# %%
import os
import shutil

base_file_name = "L_line_smoothingLength_hybridInterpolator_flux2Luminosity"
# base_file_name = "otherProperties_smoothingLength_hybridInterpolator"

base_file_dir = "/home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius"

file_name = f"{base_file_name}.txt"
destination_file_dir = f"/home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/{base_file_name}"


redshift = "3.0"
run_file_dir = "voronoi_1e6"

# %%
galaxy_type = "firebox"

for galaxy_number in range (int(1e3)):
# for galaxy_number in [0]:
    
    galaxy_name = f"gal{galaxy_number}"
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
# Out:
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal0/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal0.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal1/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal1.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal2/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal2.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal3/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal3.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal4/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal4.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal5/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal5.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal6/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal6.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal7/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal7.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal8/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal8.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal9/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal9.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal10/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal10.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal11/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal11.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal12/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal12.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal13/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal13.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal14/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal14.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal15/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal15.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal16/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal16.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal17/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal17.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal18/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal18.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal19/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal19.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal20/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal20.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal21/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal21.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal22/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal22.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal23/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal23.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal24/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal24.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal25/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal25.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal26/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal26.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal27/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal27.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal28/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal28.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal29/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal29.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal30/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal30.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal31/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal31.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal32/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal32.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal33/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal33.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal34/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal34.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal35/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal35.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal36/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal36.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal37/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal37.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal38/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal38.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal39/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal39.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal40/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal40.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal41/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal41.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal42/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal42.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal43/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal43.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal44/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal44.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal45/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal45.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal46/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal46.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal47/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal47.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal48/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal48.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal49/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal49.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal50/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal50.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal51/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal51.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal52/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal52.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal53/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal53.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal54/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal54.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal55/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal55.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal56/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal56.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal57/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal57.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal58/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal58.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal59/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal59.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal60/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal60.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal61/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal61.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal62/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal62.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal63/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal63.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal64/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal64.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal65/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal65.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal66/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal66.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal67/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal67.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal68/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal68.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal69/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal69.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal70/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal70.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal71/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal71.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal72/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal72.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal73/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal73.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal74/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal74.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal75/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal75.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal76/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal76.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal77/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal77.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal78/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal78.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal79/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal79.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal80/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal80.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal81/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal81.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal82/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal82.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal83/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal83.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal84/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal84.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal85/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal85.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal86/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal86.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal87/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal87.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal88/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal88.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal89/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal89.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal90/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal90.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal91/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal91.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal92/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal92.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal93/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal93.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal94/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal94.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal95/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal95.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal96/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal96.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal97/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal97.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal98/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal98.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal99/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal99.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal100/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal101/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal101.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal102/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal102.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal103/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal103.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal104/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal104.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal105/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal105.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal106/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal106.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal107/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal107.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal108/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal108.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal109/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal109.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal110/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal110.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal111/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal111.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal112/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal112.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal113/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal113.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal114/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal114.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal115/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal115.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal116/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal116.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal117/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal117.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal118/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal118.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal119/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal119.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal120/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal120.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal121/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal121.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal122/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal122.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal123/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal123.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal124/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal124.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal125/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal125.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal126/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal126.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal127/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal127.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal128/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal128.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal129/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal129.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal130/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal130.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal131/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal131.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal132/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal132.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal133/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal133.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal134/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal134.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal135/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal135.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal136/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal136.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal137/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal137.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal138/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal138.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal139/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/gal139.txt
#
#
# ...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal919/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal920/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal921/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal922/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal923/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal924/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal925/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal926/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal927/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal928/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal929/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal930/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal931/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal932/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal933/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal934/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal935/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal936/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal937/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal938/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal939/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal940/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal941/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal942/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal943/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal944/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal945/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal946/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal947/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal948/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal949/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal950/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal951/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal952/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal953/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal954/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal955/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal956/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal957/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal958/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal959/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal960/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal961/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal962/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal963/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal964/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal965/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal966/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal967/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal968/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal969/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal970/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal971/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal972/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal973/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal974/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal975/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal976/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal977/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal978/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal979/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal980/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal981/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal982/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal983/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal984/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal985/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal986/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal987/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal988/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal989/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal990/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal991/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal992/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal993/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal994/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal995/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal996/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal997/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal998/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal999/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt does not exist...

# %%
galaxy_type = "zoom_in"

galaxy_names = [
    "m12b_res7100_md", 
    "m12c_res7100_md",
    "m12f_res7100_md",
    "m12i_res7100_md",
    "m12m_res7100_md",
    "m12q_res7100_md",
    "m12r_res7100_md",
    "m12w_res7100_md",
    "m11d_r7100",
    "m11e_r7100",
    "m11h_r7100",
    "m11i_r7100",
    "m11q_r7100",     
]

for galaxy_name in galaxy_names:
    
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
# Out:
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12b_res7100_md/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m12b_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12c_res7100_md/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m12c_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12f_res7100_md/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m12f_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12i_res7100_md/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m12i_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12m_res7100_md/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m12m_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12q_res7100_md/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m12q_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12r_res7100_md/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m12r_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12w_res7100_md/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m12w_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11d_r7100/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m11d_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11e_r7100/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m11e_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11h_r7100/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m11h_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11i_r7100/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m11i_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11q_r7100/voronoi_1e6/L_line_smoothingLength_hybridInterpolator_flux2Luminosity.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/L_line_smoothingLength_hybridInterpolator_flux2Luminosity/m11q_r7100.txt
