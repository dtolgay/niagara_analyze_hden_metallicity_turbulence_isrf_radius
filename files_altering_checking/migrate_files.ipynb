# %%
import os
import shutil

# base_file_name = "cloudy_gas_particles"
# base_file_name = "abundance_RBFInterpolator_smoothingLength"
# base_file_name = "comprehensive_star"
base_file_name = "other_properties"
extension = "csv"

base_file_dir = "/scratch/dtolgay/post_processing_fire_outputs/skirt/runs_hden_radius"

file_name = f"{base_file_name}.{extension}"
destination_file_dir = f"/scratch/dtolgay/post_processing_fire_outputs/skirt/migrated_files_from_cita/{base_file_name}"


# redshift = "3.0"
redshift = np.nan # You have to fix this to make code working. 
run_file_dir = "voronoi_1e5"

# %%
galaxy_type = "firebox"

for galaxy_number in range (int(1e3)):
# for galaxy_number in [0]:
    
    galaxy_name = f"gal{galaxy_number}"
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.{extension}"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
# Out:
# /scratch/dtolgay/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal0/voronoi_1e5/other_properties.csv ---> /scratch/dtolgay/post_processing_fire_outputs/skirt/migrated_files_from_cita/other_properties/gal0.csv
#
#
# /scratch/dtolgay/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal1/voronoi_1e5/other_properties.csv ---> /scratch/dtolgay/post_processing_fire_outputs/skirt/migrated_files_from_cita/other_properties/gal1.csv
#
#
# /scratch/dtolgay/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal2/voronoi_1e5/other_properties.csv ---> /scratch/dtolgay/post_processing_fire_outputs/skirt/migrated_files_from_cita/other_properties/gal2.csv
#
#
# /scratch/dtolgay/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal3/voronoi_1e5/other_properties.csv ---> /scratch/dtolgay/post_processing_fire_outputs/skirt/migrated_files_from_cita/other_properties/gal3.csv
#
#
# ...

# %%
galaxy_type = "zoom_in"

galaxy_names = [
    "m12b_res7100_md", 
    "m12c_res7100_md",
    "m12f_res7100_md",
    "m12i_res7100_md",
    "m12m_res7100_md",
    "m12q_res7100_md",
    "m12r_res7100_md",
    "m12w_res7100_md",
    "m11d_r7100",
    "m11e_r7100",
    "m11h_r7100",
    "m11i_r7100",
    "m11q_r7100",     
]

for galaxy_name in galaxy_names:
    
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")

# %%
galaxy_type = "particle_split"

galaxy_names = [
    "m12i_r880_md",     
]

for galaxy_name in galaxy_names:
    
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
