# %%
import os
import shutil

base_file_name = "abundance_RBFInterpolator_smoothingLength_2"

base_file_dir = "/home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius"

file_name = f"{base_file_name}.txt"
destination_file_dir = f"/home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/{base_file_name}"


redshift = "0.0"
# redshift = np.nan # You have to fix this to make code working. 
run_file_dir = "voronoi_1e6"

# %%
galaxy_type = "firebox"

for galaxy_number in range (int(1e3)):
# for galaxy_number in [0]:
    
    galaxy_name = f"gal{galaxy_number}"
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
# Out:
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal0/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal0.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal1/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal1.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal2/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal2.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal3/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal3.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal4/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal4.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal5/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal5.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal6/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal6.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal7/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal7.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal8/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal8.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal9/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal9.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal10/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal10.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal11/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal12/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal12.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal13/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal13.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal14/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal14.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal15/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal15.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal16/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal16.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal17/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal17.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal18/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal18.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal19/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal19.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal20/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal20.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal21/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal21.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal22/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal22.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal23/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal23.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal24/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal24.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal25/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal25.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal26/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal26.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal27/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal27.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal28/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal28.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal29/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal29.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal30/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal30.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal31/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal31.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal32/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal32.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal33/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal33.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal34/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal34.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal35/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal35.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal36/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal36.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal37/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal37.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal38/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal38.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal39/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal39.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal40/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal40.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal41/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal41.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal42/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal42.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal43/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal43.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal44/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal44.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal45/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal45.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal46/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal46.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal47/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal47.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal48/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal48.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal49/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal49.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal50/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal50.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal51/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal51.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal52/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal52.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal53/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal53.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal54/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal54.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal55/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal55.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal56/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal56.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal57/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal57.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal58/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal58.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal59/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal59.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal60/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal60.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal61/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal61.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal62/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal62.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal63/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal63.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal64/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal64.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal65/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal65.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal66/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal66.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal67/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal67.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal68/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal68.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal69/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal69.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal70/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal70.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal71/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal71.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal72/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal72.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal73/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal73.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal74/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal74.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal75/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal75.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal76/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal76.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal77/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal77.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal78/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal78.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal79/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal79.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal80/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal80.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal81/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal81.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal82/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal82.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal83/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal83.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal84/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal84.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal85/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal85.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal86/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal86.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal87/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal87.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal88/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal88.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal89/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal89.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal90/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal90.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal91/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal91.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal92/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal92.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal93/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal93.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal94/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal94.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal95/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal95.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal96/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal96.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal97/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal97.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal98/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal98.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal99/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal99.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal100/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal101/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal101.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal102/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal102.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal103/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal103.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal104/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal104.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal105/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal105.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal106/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal106.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal107/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal107.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal108/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal108.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal109/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal109.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal110/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal110.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal111/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal111.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal112/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal112.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal113/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal113.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal114/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal114.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal115/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal115.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal116/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal116.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal117/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal117.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal118/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal118.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal119/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal119.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal120/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal120.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal121/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal121.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal122/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal122.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal123/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal123.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal124/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal124.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal125/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal125.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal126/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal126.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal127/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal127.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal128/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal128.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal129/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal129.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal130/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal130.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal131/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal131.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal132/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal132.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal133/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal133.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal134/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal134.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal135/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal135.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal136/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal136.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal137/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal137.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal138/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal138.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal139/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal139.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal140/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal140.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal141/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal141.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal142/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal142.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal143/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal143.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal144/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal144.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal145/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal145.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal146/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal146.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal147/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal147.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal148/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal148.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal149/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal149.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal150/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal150.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal151/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal151.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal152/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal152.txt
#
#
# ...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal949/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal949.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal950/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal950.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal951/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal951.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal952/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal952.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal953/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal953.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal954/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal954.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal955/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal955.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal956/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal956.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal957/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal957.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal958/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal958.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal959/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal959.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal960/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal960.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal961/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal961.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal962/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal962.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal963/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal963.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal964/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal964.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal965/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal965.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal966/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal966.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal967/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal967.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal968/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal968.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal969/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal969.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal970/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal970.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal971/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal971.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal972/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal972.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal973/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal973.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal974/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal974.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal975/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal975.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal976/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal976.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal977/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal977.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal978/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal978.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal979/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal979.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal980/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal980.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal981/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal981.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal982/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal982.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal983/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal984/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal984.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal985/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal985.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal986/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal986.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal987/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal987.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal988/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal988.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal989/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal989.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal990/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal990.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal991/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal991.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal992/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal992.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal993/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal993.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal994/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal994.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal995/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal995.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal996/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal996.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal997/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal997.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal998/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal998.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal999/voronoi_1e6/abundance_RBFInterpolator_smoothingLength_2.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/abundance_RBFInterpolator_smoothingLength_2/gal999.txt

# %%
galaxy_type = "zoom_in"

galaxy_names = [
    "m12b_res7100_md", 
    "m12c_res7100_md",
    "m12f_res7100_md",
    "m12i_res7100_md",
    "m12m_res7100_md",
    "m12q_res7100_md",
    "m12r_res7100_md",
    "m12w_res7100_md",
    "m11d_r7100",
    "m11e_r7100",
    "m11h_r7100",
    "m11i_r7100",
    "m11q_r7100",     
]

for galaxy_name in galaxy_names:
    
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")

# %%
galaxy_type = "particle_split"

galaxy_names = [
    "m12i_r880_md",     
]

for galaxy_name in galaxy_names:
    
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
