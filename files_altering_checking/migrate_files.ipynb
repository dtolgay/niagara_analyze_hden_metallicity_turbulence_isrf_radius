# %%
import os
import shutil

# base_file_name = "cloudy_gas_particles" 
# base_file_name = "otherProperties_nearestCloudyRun"
# base_file_name = "L_line_smoothingLength_hybridInterpolator_flux2Luminosity"
# base_file_name = "otherProperties_smoothingLength_hybridInterpolator"
# base_file_name = "L_line_smoothingLength_nearestNDInterpolator_flux2Luminosity"
# base_file_name = "otherProperties_smoothingLength_nearestNDInterpolator"
# base_file_name = "L_line_averageSobolevH_nearestNDInterpolator_flux2Luminosity"
base_file_name = "otherProperties_averageSobolevH_nearestNDInterpolator"

base_file_dir = "/home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius"

file_name = f"{base_file_name}.txt"
destination_file_dir = f"/home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/{base_file_name}"


redshift = "3.0"
run_file_dir = "voronoi_1e6"

# %%
galaxy_type = "firebox"

for galaxy_number in range (50):
# for galaxy_number in [0]:
    
    galaxy_name = f"gal{galaxy_number}"
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
# Out:
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal0/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal0.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal1/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal1.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal2/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal2.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal3/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal3.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal4/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal4.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal5/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal5.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal6/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal6.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal7/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal7.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal8/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal8.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal9/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal9.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal10/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal10.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal11/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal11.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal12/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal12.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal13/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal13.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal14/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal14.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal15/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal15.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal16/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal16.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal17/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal17.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal18/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal18.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal19/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal19.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal20/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal20.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal21/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal21.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal22/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal22.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal23/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal23.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal24/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal24.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal25/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal25.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal26/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal26.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal27/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal27.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal28/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal28.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal29/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal29.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal30/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal30.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal31/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal31.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal32/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal32.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal33/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal33.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal34/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal34.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal35/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal35.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal36/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal36.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal37/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal37.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal38/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal38.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal39/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal39.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal40/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal40.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal41/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal41.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal42/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal42.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal43/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal43.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal44/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal44.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal45/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal45.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal46/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal46.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal47/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal47.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal48/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal48.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal49/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/gal49.txt

# %%
galaxy_type = "zoom_in"

galaxy_names = [
    "m12b_res7100_md", 
    "m12c_res7100_md",
    "m12f_res7100_md",
    "m12i_res7100_md",
    "m12m_res7100_md",
    "m12q_res7100_md",
    "m12r_res7100_md",
    "m12w_res7100_md",
    "m11d_r7100",
    "m11e_r7100",
    "m11h_r7100",
    "m11i_r7100",
    "m11q_r7100",     
]

for galaxy_name in galaxy_names:
    
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
# Out:
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12b_res7100_md/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m12b_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12c_res7100_md/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m12c_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12f_res7100_md/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m12f_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12i_res7100_md/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m12i_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12m_res7100_md/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m12m_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12q_res7100_md/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m12q_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12r_res7100_md/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m12r_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12w_res7100_md/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m12w_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11d_r7100/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m11d_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11e_r7100/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m11e_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11h_r7100/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m11h_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11i_r7100/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m11i_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11q_r7100/voronoi_1e6/otherProperties_averageSobolevH_nearestNDInterpolator.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_averageSobolevH_nearestNDInterpolator/m11q_r7100.txt
