# %%
import os
import shutil

# base_file_name = "cloudy_gas_particles" 
base_file_name = "otherProperties_nearestCloudyRun"
base_file_dir = "/home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius"

file_name = f"{base_file_name}.txt"
destination_file_dir = f"/home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/{base_file_name}"


redshift = "0.0"
run_file_dir = "voronoi_1e6"

# %%
galaxy_type = "firebox"

for galaxy_number in range (1000):
    
    galaxy_name = f"gal{galaxy_number}"
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
# Out:
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal0/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal0.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal1/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal1.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal2/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal2.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal3/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal4/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal5/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal6/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal7/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal8/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal8.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal9/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal9.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal10/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal11/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal12/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal13/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal14/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal15/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal16/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal17/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal18/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal19/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal20/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal20.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal21/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal21.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal22/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal22.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal23/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal23.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal24/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal24.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal25/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal25.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal26/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal26.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal27/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal27.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal28/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal29/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal30/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal31/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal32/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal33/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal34/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal35/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal36/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal37/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal38/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal39/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal40/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal40.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal41/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal41.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal42/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal42.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal43/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal43.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal44/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal44.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal45/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal45.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal46/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal46.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal47/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal47.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal48/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal49/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal50/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal51/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal52/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal53/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal54/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal55/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal56/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal57/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal58/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal59/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal60/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal60.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal61/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal61.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal62/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal62.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal63/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal63.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal64/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal64.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal65/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal65.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal66/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal66.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal67/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal67.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal68/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal68.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal69/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal69.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal70/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal70.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal71/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal71.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal72/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal72.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal73/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal73.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal74/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal74.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal75/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal75.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal76/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal76.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal77/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal77.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal78/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal78.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal79/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal79.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal80/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal80.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal81/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal81.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal82/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal82.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal83/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal83.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal84/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal84.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal85/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal85.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal86/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal86.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal87/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal87.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal88/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal88.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal89/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal89.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal90/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal90.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal91/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal91.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal92/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal92.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal93/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal93.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal94/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal94.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal95/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal96/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal97/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal98/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal99/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal100/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal101/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal101.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal102/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal102.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal103/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal103.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal104/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal104.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal105/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal105.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal106/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal106.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal107/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal107.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal108/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal108.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal109/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal109.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal110/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal110.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal111/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal111.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal112/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal112.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal113/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal113.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal114/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal114.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal115/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal115.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal116/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal116.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal117/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal117.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal118/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal118.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal119/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal119.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal120/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal120.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal121/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal121.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal122/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal122.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal123/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal123.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal124/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal124.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal125/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal125.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal126/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal126.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal127/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal127.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal128/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal128.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal129/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal129.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal130/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal130.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal131/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal131.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal132/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal132.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal133/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal133.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal134/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal134.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal135/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal135.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal136/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal136.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal137/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal137.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal138/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal138.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal139/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal139.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal140/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal140.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal141/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal141.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal142/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal142.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal143/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal143.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal144/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal144.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal145/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal145.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal146/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal146.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal147/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal147.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal148/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal148.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal149/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal149.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal150/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal150.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal151/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal151.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal152/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal152.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal153/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal153.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal154/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal154.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal155/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal155.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal156/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal156.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal157/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal157.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal158/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal158.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal159/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal159.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal160/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal160.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal161/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal161.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal162/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal162.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal163/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal163.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal164/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal164.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal165/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal165.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal166/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal166.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal167/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal167.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal168/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal168.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal169/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal169.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal170/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal170.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal171/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal171.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal172/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal172.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal173/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal173.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal174/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal174.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal175/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal175.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal176/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal176.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal177/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal177.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal178/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal178.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal179/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal179.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal180/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal180.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal181/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal181.txt
#
#
# ...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal946/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal946.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal947/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal947.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal948/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal948.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal949/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal949.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal950/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal950.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal951/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal951.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal952/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal952.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal953/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal953.txt
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal954/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal954.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal955/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal955.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal956/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal956.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal957/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal957.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal958/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal958.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal959/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal959.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal960/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal960.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal961/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal961.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal962/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal962.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal963/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal963.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal964/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal964.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal965/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal965.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal966/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal966.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal967/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal967.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal968/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal968.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal969/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal969.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal970/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal970.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal971/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal971.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal972/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal972.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal973/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal973.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal974/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal974.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal975/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal975.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal976/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal976.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal977/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal977.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal978/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal978.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal979/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal979.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal980/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal980.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal981/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal981.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal982/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal982.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal983/voronoi_1e6/otherProperties_nearestCloudyRun.txt does not exist...
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal984/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal984.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal985/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal985.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal986/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal986.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal987/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal987.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal988/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal988.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal989/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal989.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal990/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal990.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal991/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal991.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal992/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal992.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal993/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal993.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal994/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal994.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal995/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal995.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal996/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal996.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal997/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal997.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal998/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal998.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal999/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/gal999.txt

# %%
galaxy_type = "zoom_in"

galaxy_names = [
    "m12b_res7100_md", 
    "m12c_res7100_md",
    "m12f_res7100_md",
    "m12i_res7100_md",
    "m12m_res7100_md",
    "m12q_res7100_md",
    "m12r_res7100_md",
    "m12w_res7100_md",
    "m11d_r7100",
    "m11e_r7100",
    "m11h_r7100",
    "m11i_r7100",
    "m11q_r7100",     
]

for galaxy_name in galaxy_names:
    
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
# Out:
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m12b_res7100_md/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m12b_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m12c_res7100_md/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m12c_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m12f_res7100_md/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m12f_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m12i_res7100_md/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m12i_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m12m_res7100_md/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m12m_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m12q_res7100_md/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m12q_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m12r_res7100_md/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m12r_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m12w_res7100_md/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m12w_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m11d_r7100/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m11d_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m11e_r7100/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m11e_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m11h_r7100/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m11h_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m11i_r7100/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m11i_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z0.0/m11q_r7100/voronoi_1e6/otherProperties_nearestCloudyRun.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/otherProperties_nearestCloudyRun/m11q_r7100.txt
