# %%
import os
import shutil

base_file_name = "cloudy_gas_particles"
# base_file_name = "abundance_RBFInterpolator_smoothingLength"
# base_file_name = "comprehensive_star"
extension = "txt"

base_file_dir = "/home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius"

file_name = f"{base_file_name}.{extension}"
destination_file_dir = f"/home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/{base_file_name}"


redshift = "3.0"
# redshift = np.nan # You have to fix this to make code working. 
run_file_dir = "voronoi_1e5"

# %%
galaxy_type = "firebox"

for galaxy_number in range (int(1e3)):
# for galaxy_number in [0]:
    
    galaxy_name = f"gal{galaxy_number}"
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
# Out:
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal0/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal0.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal1/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal1.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal2/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal2.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal3/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal3.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal4/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal4.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal5/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal5.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal6/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal6.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal7/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal7.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal8/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal8.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal9/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal9.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal10/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal10.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal11/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal11.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal12/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal12.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal13/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal13.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal14/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal14.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal15/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal15.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal16/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal16.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal17/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal17.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal18/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal18.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal19/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal19.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal20/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal20.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal21/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal21.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal22/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal22.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal23/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal23.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal24/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal24.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal25/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal25.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal26/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal26.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal27/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal27.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal28/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal28.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal29/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal29.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal30/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal30.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal31/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal31.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal32/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal32.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal33/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal33.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal34/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal34.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal35/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal35.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal36/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal36.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal37/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal37.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal38/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal38.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal39/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal39.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal40/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal40.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal41/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal41.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal42/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal42.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal43/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal43.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal44/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal44.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal45/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal45.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal46/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal46.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal47/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal47.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal48/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal48.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal49/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal49.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal50/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal50.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal51/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal51.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal52/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal52.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal53/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal53.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal54/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal54.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal55/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal55.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal56/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal56.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal57/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal57.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal58/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal58.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal59/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal59.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal60/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal60.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal61/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal61.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal62/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal62.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal63/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal63.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal64/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal64.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal65/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal65.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal66/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal66.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal67/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal67.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal68/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal68.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal69/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal69.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal70/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal70.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal71/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal71.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal72/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal72.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal73/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal73.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal74/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal74.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal75/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal75.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal76/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal76.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal77/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal77.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal78/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal78.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal79/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal79.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal80/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal80.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal81/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal81.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal82/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal82.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal83/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal83.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal84/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal84.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal85/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal85.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal86/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal86.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal87/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal87.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal88/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal88.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal89/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal89.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal90/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal90.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal91/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal91.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal92/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal92.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal93/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal93.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal94/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal94.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal95/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal95.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal96/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal96.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal97/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal97.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal98/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal98.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal99/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal99.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal100/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal101/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal101.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal102/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal102.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal103/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal103.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal104/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal104.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal105/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal105.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal106/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal106.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal107/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal107.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal108/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal108.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal109/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal109.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal110/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal110.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal111/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal111.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal112/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal112.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal113/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal113.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal114/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal114.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal115/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal115.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal116/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal116.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal117/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal117.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal118/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal118.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal119/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal119.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal120/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal120.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal121/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal121.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal122/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal122.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal123/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal123.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal124/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal124.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal125/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal125.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal126/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal126.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal127/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal127.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal128/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal128.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal129/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal129.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal130/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal130.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal131/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal131.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal132/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal132.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal133/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal133.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal134/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal134.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal135/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal135.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal136/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal136.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal137/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal137.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal138/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal138.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal139/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal139.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal140/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal140.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal141/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal141.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal142/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal142.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal143/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal143.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal144/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal144.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal145/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal145.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal146/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal146.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal147/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal147.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal148/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal148.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal149/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal149.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal150/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal150.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal151/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal151.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal152/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal152.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal153/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal153.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal154/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal154.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal155/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal155.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal156/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal156.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal157/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal157.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal158/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal158.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal159/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal159.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal160/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal160.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal161/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal161.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal162/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal162.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal163/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal163.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal164/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal164.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal165/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal165.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal166/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal166.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal167/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal167.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal168/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal168.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal169/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal169.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal170/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal170.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal171/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal171.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal172/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal172.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal173/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal173.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal174/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal174.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal175/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal175.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal176/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal176.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal177/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal177.txt
#
#
# ...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal941/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal941.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal942/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal942.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal943/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal943.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal944/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal944.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal945/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal945.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal946/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal946.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal947/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal947.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal948/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal948.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal949/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal949.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal950/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal950.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal951/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal951.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal952/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal952.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal953/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal953.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal954/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal954.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal955/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal955.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal956/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal956.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal957/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal957.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal958/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal958.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal959/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal959.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal960/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal960.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal961/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal961.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal962/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal962.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal963/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal963.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal964/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal964.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal965/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal965.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal966/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal966.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal967/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal967.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal968/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal968.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal969/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal969.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal970/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal970.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal971/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal971.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal972/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal972.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal973/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal973.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal974/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal974.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal975/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal975.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal976/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal976.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal977/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal977.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal978/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal978.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal979/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal979.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal980/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal980.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal981/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal981.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal982/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal982.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal983/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal983.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal984/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal984.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal985/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal985.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal986/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal986.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal987/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal987.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal988/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal988.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal989/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal989.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal990/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal990.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal991/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal991.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal992/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal992.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal993/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal993.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal994/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal994.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal995/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal995.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal996/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal996.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal997/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal997.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal998/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal998.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z3.0/gal999/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/gal999.txt

# %%
galaxy_type = "zoom_in"

galaxy_names = [
    "m12b_res7100_md", 
    "m12c_res7100_md",
    "m12f_res7100_md",
    "m12i_res7100_md",
    "m12m_res7100_md",
    "m12q_res7100_md",
    "m12r_res7100_md",
    "m12w_res7100_md",
    "m11d_r7100",
    "m11e_r7100",
    "m11h_r7100",
    "m11i_r7100",
    "m11q_r7100",     
]

for galaxy_name in galaxy_names:
    
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
# Out:
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12b_res7100_md/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m12b_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12c_res7100_md/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m12c_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12f_res7100_md/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m12f_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12i_res7100_md/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m12i_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12m_res7100_md/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m12m_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12q_res7100_md/voronoi_1e5/cloudy_gas_particles.txt does not exist...
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12r_res7100_md/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m12r_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m12w_res7100_md/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m12w_res7100_md.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11d_r7100/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m11d_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11e_r7100/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m11e_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11h_r7100/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m11h_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11i_r7100/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m11i_r7100.txt
#
#
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/zoom_in/z3.0/m11q_r7100/voronoi_1e5/cloudy_gas_particles.txt ---> /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/migrated_files_from_cita/cloudy_gas_particles/m11q_r7100.txt

# %%
galaxy_type = "particle_split"

galaxy_names = [
    "m12i_r880_md",     
]

for galaxy_name in galaxy_names:
    
    file_dir = f"{base_file_dir}/{galaxy_type}/z{redshift}/{galaxy_name}/{run_file_dir}"

    try:  
        # Check if file exits
        file_path = f"{file_dir}/{file_name}"

        if os.path.exists(file_path):
            destination_file_path = f"{destination_file_dir}/{galaxy_name}.txt"
            # Copy the file with it's new name
            shutil.copy(file_path, destination_file_path)            
            
            print(f"{file_path} ---> {destination_file_path}")
        
        else: 
            print(f"{file_path} does not exist...")
        
    except Exception as e:
        print(f"Error occured:\n{e}")
        
    print("\n")
# Out:
# /home/m/murray/dtolgay/scratch/post_processing_fire_outputs/skirt/runs_hden_radius/particle_split/z3.0/m12i_r880_md/voronoi_1e5/cloudy_gas_particles.txt does not exist...
