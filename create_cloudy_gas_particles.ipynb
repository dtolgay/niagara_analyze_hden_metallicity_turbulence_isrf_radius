# %%
import sys
sys.path.append("/scratch/m/murray/dtolgay/")

import numpy as np 
from tools import constants
import os

# %%
redshift = "3.0"
directory_name = "voronoi_1e5"

# %%
def main(galaxy_name, galaxy_type, redshift, directory_name):
    
    print(f"----------------------- {galaxy_name} -----------------------")
    
#     directory_name = "voronoi_1e6"
#     directory_name = "zstar_doubled_voronoi_1e6"
#     directory_name = "seperated_firebox_galaxies"
#     directory_name = "40kpc_voronoi_1e5"
#     directory_names = ["voronoi_3e6", "voronoi_3e5", "voronoi_1e4"]
    
    directory_path = f"/gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/{galaxy_type}/z{redshift}/{galaxy_name}/{directory_name}"        
    write_file_name = f"{directory_path}/cloudy_gas_particles.txt"


    ## Check if cloudy_gas_particles.txt exits. If exist, do not create it. 
    print("\n")
    if os.path.isfile(write_file_name):
        print(f"{write_file_name} exits, the code is stopped.")
        return 0
    else: 
        print(f"{write_file_name} doen't exist. Continuing....")

    # Read comprehensive_gas 
    print(f"Starting reading {directory_path}/comprehensive_gas.txt")    
    comprehensive_gas = np.loadtxt(fname=f"{directory_path}/comprehensive_gas.txt")
    print(f"Finished reading {directory_path}/comprehensive_gas.txt")

    # Read isrf_gas
    print(f"Starting reading {directory_path}/isrf_gas.txt")        
    isrf_gas = np.loadtxt(fname=f"{directory_path}/isrf_gas.txt", skiprows=1)
    print(f"Finished reading {directory_path}/isrf_gas.txt")    

    stacked_array = np.hstack((comprehensive_gas, isrf_gas))

    # Normalize metallicity to solar metallicity 
    stacked_array[:,5] /= constants.solar_metallicity

    # Write to a file 
    header = f"""Gas particles for {galaxy_name} galaxy
    Column 0: x-coordinate (pc)
    Column 1: y-coordinate (pc)
    Column 2: z-coordinate (pc)
    Column 3: smoothing length (pc)
    Column 4: mass (Msolar)
    Column 5: metallicity (Zsolar)
    Column 6: temperature (K)
    Column 7: vx (km/s)
    Column 8: vy (km/s)
    Column 9: vz (km/s)
    Column 10: hydrogen density (cm^-3)
    Column 11: radius (pc)
    Column 12: sfr (Msolar/yr)
    Column 13: turbulence (km/s)
    Column 14: density (gr/cm^-3)
    Column 15: mu_theoretical (1)
    Column 16: average_sobolev_smoothingLength (pc)    
    Column 17: index (1)
    Column 18: isrf [G0]
    """

    np.savetxt(fname=write_file_name, X = stacked_array, fmt='%.8e', header=header)
    print(f"{write_file_name} is written!")    
    
    return stacked_array

# %%
# main(
#     galaxy_name="m12i_res7100_md",
#     galaxy_type="zoom_in",
#     redshift="0.0",
# )

# %%
# %%time

######################## firebox
for i in range (0, int(1e3)):
# for i in [0]:
    try:
        galaxy_name = f"gal{i}"
        galaxy_type = "firebox"
        main(galaxy_name, galaxy_type, redshift, directory_name)

        print("\n\n")
        
    except IOError as e:
        print(f"Unable to create cloudy_gas_particles.txt\n {e}")
# Out:
# ----------------------- gal0 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal0/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal0/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal0/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal0/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal0/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal0/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal1 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal1/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal1/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal1/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal1/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal1/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal1/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal2 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal2/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal2/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal2/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal2/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal2/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal2/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal3 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal3/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal3/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal3/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal3/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal3/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal3/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal4 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal4/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal4/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal4/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal4/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal4/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal4/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal5 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal5/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal5/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal5/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal5/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal5/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal5/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal6 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal6/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal6/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal6/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal6/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal6/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal6/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal7 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal7/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal7/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal7/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal7/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal7/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal7/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal8 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal8/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal8/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal8/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal8/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal8/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal8/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal9 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal9/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal9/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal9/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal9/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal9/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal9/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal10 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal10/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal10/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal10/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal10/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal10/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal10/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal11 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal11/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal11/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal11/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal11/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal11/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal11/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal12 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal12/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal12/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal12/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal12/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal12/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal12/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal13 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal13/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal13/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal13/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal13/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal13/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal13/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal14 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal14/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal14/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal14/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal14/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal14/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal14/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal15 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal15/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal15/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal15/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal15/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal15/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal15/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal16 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal16/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal16/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal16/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal16/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal16/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal16/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal17 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal17/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal17/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal17/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal17/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal17/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal17/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal18 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal18/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal18/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal18/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal18/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal18/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal18/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal19 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal19/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal19/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal19/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal19/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal19/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal19/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal20 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal20/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal20/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal20/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal20/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal20/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal20/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal21 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal21/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal21/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal21/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal21/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal21/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal21/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal22 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal22/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal22/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal22/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal22/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal22/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal22/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal23 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal23/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal23/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal23/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal23/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal23/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal23/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal24 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal24/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal24/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal24/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal24/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal24/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal24/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal25 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal25/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal25/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal25/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal25/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal25/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal25/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal26 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal26/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal26/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal26/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal26/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal26/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal26/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal27 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal27/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal27/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal27/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal27/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal27/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal27/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal28 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal28/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal28/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal28/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal28/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal28/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal28/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal29 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal29/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal29/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal29/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal29/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal29/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal29/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal30 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal30/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal30/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal30/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal30/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal30/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal30/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal31 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal31/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal31/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal31/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal31/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal31/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal31/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal32 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal32/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal32/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal32/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal32/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal32/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal32/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal33 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal33/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal33/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal33/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal33/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal33/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal33/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal34 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal34/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal34/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal34/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal34/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal34/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal34/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal35 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal35/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal35/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal35/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal35/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal35/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal35/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal36 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal36/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal36/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal36/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal36/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal36/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal36/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal37 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal37/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal37/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal37/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal37/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal37/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal37/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal38 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal38/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal38/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal38/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal38/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal38/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal38/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal39 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal39/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal39/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal39/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal39/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal39/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal39/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal40 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal40/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal40/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal40/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal40/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal40/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal40/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal41 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal41/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal41/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal41/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal41/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal41/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal41/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal42 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal42/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal42/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal42/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal42/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal42/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal42/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal43 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal43/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal43/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal43/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal43/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal43/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal43/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal44 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal44/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal44/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal44/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal44/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal44/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal44/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal45 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal45/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal45/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal45/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal45/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal45/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal45/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal46 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal46/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal46/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal46/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal46/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal46/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal46/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal47 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal47/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal47/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal47/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal47/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal47/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal47/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal48 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal48/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal48/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal48/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal48/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal48/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal48/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal49 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal49/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal49/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal49/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal49/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal49/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal49/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal50 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal50/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal50/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal50/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal50/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal50/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal50/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal51 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal51/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal51/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal51/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal51/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal51/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal51/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal52 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal52/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal52/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal52/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal52/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal52/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal52/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal53 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal53/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal53/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal53/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal53/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal53/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal53/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal54 -----------------------
#
#
# ...
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal982/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal982/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal982/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal982/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal982/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal983 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal983/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal983/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal983/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal983/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal983/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal983/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal984 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal984/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal984/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal984/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal984/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal984/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal984/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal985 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal985/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal985/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal985/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal985/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal985/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal985/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal986 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal986/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal986/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal986/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal986/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal986/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal986/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal987 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal987/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal987/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal987/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal987/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal987/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal987/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal988 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal988/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal988/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal988/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal988/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal988/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal988/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal989 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal989/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal989/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal989/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal989/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal989/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal989/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal990 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal990/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal990/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal990/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal990/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal990/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal990/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal991 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal991/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal991/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal991/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal991/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal991/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal991/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal992 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal992/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal992/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal992/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal992/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal992/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal992/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal993 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal993/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal993/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal993/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal993/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal993/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal993/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal994 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal994/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal994/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal994/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal994/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal994/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal994/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal995 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal995/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal995/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal995/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal995/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal995/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal995/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal996 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal996/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal996/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal996/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal996/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal996/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal996/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal997 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal997/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal997/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal997/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal997/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal997/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal997/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal998 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal998/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal998/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal998/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal998/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal998/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal998/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# ----------------------- gal999 -----------------------
#
#
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal999/voronoi_1e5/cloudy_gas_particles.txt doen't exist. Continuing....
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal999/voronoi_1e5/comprehensive_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal999/voronoi_1e5/comprehensive_gas.txt
# Starting reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal999/voronoi_1e5/isrf_gas.txt
# Finished reading /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal999/voronoi_1e5/isrf_gas.txt
# /gpfs/fs0/scratch/r/rbond/dongwooc/scratch_rwa/doga/runs_hden_radius/firebox/z3.0/gal999/voronoi_1e5/cloudy_gas_particles.txt is written!
#
#
#
# CPU times: user 22min 47s, sys: 31.8 s, total: 23min 19s
# Wall time: 24min 52s

# %%
######################## zoom_in
galaxy_names = [
    "m12b_res7100_md", 
    "m12c_res7100_md",
    "m12f_res7100_md",
    "m12i_res7100_md",
    "m12m_res7100_md",
    "m12q_res7100_md",
    "m12r_res7100_md",
    "m12w_res7100_md",
    "m11d_r7100",
    "m11e_r7100",
    "m11h_r7100",
    "m11i_r7100",
    "m11q_r7100",    
]

for galaxy_name in galaxy_names: 
    galaxy_type = "zoom_in"
    main(galaxy_name, galaxy_type, redshift, directory_name)
    
    print("\n\n")

# %%
######################## particle_split
galaxy_names = [
    "m12i_r880_md",
]

for galaxy_name in galaxy_names: 
    galaxy_type = "particle_split"
    main(galaxy_name, galaxy_type, redshift, directory_name)
    
    print("\n\n")
