# %%
import numpy as np
import pandas as pd
from pysr import PySRRegressor
# Out:
# [juliapkg] Found dependencies: /gpfs/fs0/scratch/m/murray/dtolgay/post_processing_fire_outputs/skirt/python_files/analyze_hden_metallicity_turbulence_isrf_radius/.venv/lib/python3.11/site-packages/juliapkg/juliapkg.json
# [juliapkg] Found dependencies: /gpfs/fs0/scratch/m/murray/dtolgay/post_processing_fire_outputs/skirt/python_files/analyze_hden_metallicity_turbulence_isrf_radius/.venv/lib/python3.11/site-packages/juliacall/juliapkg.json
# [juliapkg] Found dependencies: /gpfs/fs0/scratch/m/murray/dtolgay/post_processing_fire_outputs/skirt/python_files/analyze_hden_metallicity_turbulence_isrf_radius/.venv/lib/python3.11/site-packages/pysr/juliapkg.json
# [juliapkg] Locating Julia =1.10.0, ^1.10.3
# [juliapkg] Querying Julia versions from https://julialang-s3.julialang.org/bin/versions.json
# ...

# %%
# Create synthetic data
np.random.seed(0)
X = np.random.randn(100, 2)  # 100 samples, 2 features
y = X[:, 0] * np.sin(X[:, 1]) + X[:, 1]**2  # True relationship

# Define the symbolic regressor
model = PySRRegressor(
    niterations=40,               # Number of evolutionary iterations
    binary_operators=["+", "-", "*", "/"],
    unary_operators=["sin", "cos", "exp", "log"],
    model_selection="best",      # Choose the best model by loss
    elementwise_loss="loss(x, y) = (x - y)^2",  # Mean squared error
    verbosity=1,
)

# Fit the model
model.fit(X, y)

# Show best equation
print(model)

# Predict using symbolic model
y_pred = model.predict(X)
