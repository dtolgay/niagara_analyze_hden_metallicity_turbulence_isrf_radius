# %%
import pandas as pd 
import numpy as np 

from tools_tolgay import functions_readfiles as readfiles

import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['mathtext.fontset'] = 'cm'
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16
rcParams['figure.figsize'] = (12, 6)
rcParams['figure.dpi'] = 100

# %%
base_fdir = "/scratch/dtolgay/cloudy_runs/z_0/m12i_res7100_md_test"

runs = {
    # "expected_from_flux": {
    #     "label": "L/A expected",
    #     "file_name": "luminosity_from_flux_smoothingLength_expected.txt",
    #     "color": "black",
    # },
    # "interpolated_from_flux_RBFInterpolator": {
    #     "label": "L/A RBFInterpolator",
    #     "file_name": "luminosity_from_flux_RBFInterpolator_smoothingLength_interpolation.txt",
    #     "color": "green",
    # },
    # "expected_from_luminosity_per_mass": {
    #     "label": "L/M expected",
    #     "file_name": "luminosity_from_luminosity_per_mass_smoothingLength_expected.txt",
    #     "color": "gray",
    # },
    # "interpolated_from_luminosity_per_mass_RBFInterpolator": {
    #     "label": "L/M RBFInterpolator",
    #     "file_name": "luminosity_from_luminosity_per_mass_RBFInterpolator_smoothingLength_interpolation.txt",
    #     "color": "blue",
    # },
    # "interpolated_from_luminosity_per_mass_LinearNDInterpolator": {
    #     "label": "L/M LinearNDInterpolator",
    #     "file_name": "luminosity_from_luminosity_per_mass_LinearNDInterpolator_smoothingLength_interpolation.txt",
    #     "color": "orange",
    # },
    # "interpolator_from_luminosity_per_mass_nearestNDInterpolator": {
    #     "label": "L/M nearestNDInterpolator",
    #     "file_name": "luminosity_from_luminosity_per_mass_NearestNDInterpolator_smoothingLength_interpolation.txt",
    #     "color": "red",
    # },
    # "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_LinearNDInterpolator": {
    #     "label": "L/M/4π LinearNDInterpolator",
    #     "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_LinearNDInterpolator_smoothingLength_interpolation.txt",
    #     "color": "orange",
    # },
    # "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_NearestNDInterpolator": {
    #     "label": "L/M/4π NearestNDInterpolator",
    #     "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_NearestNDInterpolator_smoothingLength_interpolation.txt",
    #     "color": "red",
    # },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N100": {
        "label": "L/M/4π RBFInterpolator N100",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N100_smoothingLength_interpolation.txt",
        "color": "purple",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200": {
        "label": "L/M/4π RBFInterpolator N200",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200_smoothingLength_interpolation.txt",
        "color": "magenta",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N300": {
        "label": "L/M/4π RBFInterpolator N300",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N300_smoothingLength_interpolation.txt",
        "color": "cyan",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N1000": {
        "label": "L/M/4π RBFInterpolator N1000",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N1000_smoothingLength_interpolation.txt",
        "color": "blue",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N10000": {
        "label": "L/M/4π RBFInterpolator N10000",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N10000_smoothingLength_interpolation.txt",
        "color": "green",
    },
    "expected_from_luminosity_per_mass_by_dividing_to_4pi": {
        "label": "L/M/4π expected",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_smoothingLength_expected.txt",
        "color": "brown",
    },
}

for run in runs.keys():
    path_to_file = f"{base_fdir}/{runs[run]['file_name']}"
    print(path_to_file)
    runs[run]["data"], _ = readfiles.read_interpolated_files_usingFilePath2(path = path_to_file, interpolation_type = "line_emissions")
# Out:
# /scratch/dtolgay/cloudy_runs/z_0/m12i_res7100_md_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N100_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/m12i_res7100_md_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/m12i_res7100_md_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N300_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/m12i_res7100_md_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N1000_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/m12i_res7100_md_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N10000_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/m12i_res7100_md_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_smoothingLength_expected.txt

# %%
# Plot the distribution of luminosities for different interpolators

line = "L_co_10"
bins = np.linspace(-5, 8, 100)

for run in runs.keys():

    total_luminosity = np.sum(runs[run]["data"][line])

    luminosities = runs[run]["data"][line]
    plt.hist(
        np.log10(luminosities), 
        bins = bins, alpha = 0.5, 
        label = f"run: {runs[run]['label']}, total L = {total_luminosity:.2e} K km/s pc^2", 
        color = runs[run]["color"]
    )
    plt.axvline(np.median(np.log10(luminosities)), color = runs[run]["color"], linestyle = "--")


plt.xlabel(f"{line} [K km/s pc^2]")
plt.ylabel("Number of gas particles")
plt.title("m12i res7100 md test")
plt.legend()

figure_name = f"luminosity_distribution_{line}_m12i_res7100_md_test.png"
plt.savefig(figure_name)
print(f"Figure saved as {figure_name}")
plt.show()





plt.scatter(
    np.log10(runs["expected_from_luminosity_per_mass_by_dividing_to_4pi"]["data"][line]),
    np.log10(runs["interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200"]["data"][line]), 
    label = "expected", color = "black"
)
plt.plot([ -5, 6], [-5, 6], linestyle = "--", color = "red")
plt.xlabel(f"expected {line} [K km/s pc^2]")
plt.ylabel(f"RBFInterpolator_N200 {line} [K km/s pc^2]")
plt.title("m12i res7100 md test")
plt.legend()
plt.xlim(-10, 6)
plt.ylim(-10, 6)
plt.show()
# Out:
# Figure saved as luminosity_distribution_L_co_10_m12i_res7100_md_test.png

# %%
# ## From flux
# plt.figure()
# plt.scatter(
#     np.log10(runs["expected_from_flux"]["data"][line]), 
#     np.log10(runs["interpolated_from_flux_RBFInterpolator"]["data"][line]), 
#     alpha = 0.5, color = "green", label = "L/A RBFInterpolator"
# )
# plt.plot([-5, 8], [-5, 8], color = "black", linestyle = "--")
# plt.xlabel("Expected")
# plt.ylabel("RBF Interpolated")
# plt.xlim(-10, 8)
# plt.ylim(-10, 8)
# plt.legend()

# ## from luminosity per mass
# plt.figure()
# plt.scatter(
#     np.log10(runs["expected_from_luminosity_per_mass"]["data"][line]), 
#     np.log10(runs["interpolated_from_luminosity_per_mass_RBFInterpolator"]["data"][line]), 
#     alpha = 0.5, color = "blue", label = "L/M RBFInterpolator"
# )
# plt.xlabel("Expected")
# plt.ylabel("RBF Interpolated")
# plt.plot([-5, 8], [-5, 8], color = "black", linestyle = "--")
# plt.xlim(-10, 8)
# plt.ylim(-10, 8)
# plt.legend()

# %% [markdown]
# ### An another galaxy to check

# %%
base_fdir = "/scratch/dtolgay/cloudy_runs/z_0/gal600_test"

runs_gal600 = {
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N100": {
        "label": "L/M/4π RBFInterpolator N100",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N100_smoothingLength_interpolation.txt",
        "color": "purple",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200": {
        "label": "L/M/4π RBFInterpolator N200",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200_smoothingLength_interpolation.txt",
        "color": "magenta",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N300": {
        "label": "L/M/4π RBFInterpolator N300",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N300_smoothingLength_interpolation.txt",
        "color": "cyan",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N1000": {
        "label": "L/M/4π RBFInterpolator N1000",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N1000_smoothingLength_interpolation.txt",
        "color": "blue",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N10000": {
        "label": "L/M/4π RBFInterpolator N10000",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N10000_smoothingLength_interpolation.txt",
        "color": "green",
    },
    "expected_from_luminosity_per_mass_by_dividing_to_4pi": {
        "label": "L/M/4π expected",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_smoothingLength_expected.txt",
        "color": "brown",
    },
}

for run in runs_gal600.keys():
    try:
        path_to_file = f"{base_fdir}/{runs_gal600[run]['file_name']}"
        print(path_to_file)
        runs_gal600[run]["data"], _ = readfiles.read_interpolated_files_usingFilePath2(path = path_to_file, interpolation_type = "line_emissions")
    except:
        path_to_file = f"{base_fdir}/{runs_gal600[run]['file_name']}"
        print(f"----------- {path_to_file} not found")




# Plot the distribution of luminosities for different interpolators

line = "L_co_10"
bins = np.linspace(-5, 8, 100)

for run in runs_gal600.keys():

    try:
        total_luminosity = np.sum(runs_gal600[run]["data"][line])

        luminosities = runs_gal600[run]["data"][line]
        plt.hist(
            np.log10(luminosities), 
            bins = bins, alpha = 0.5, 
            label = f"run: {runs_gal600[run]['label']}, total L = {total_luminosity:.2e} K km/s pc^2", 
            color = runs_gal600[run]["color"]
        )
        plt.axvline(np.median(np.log10(luminosities)), color = runs_gal600[run]["color"], linestyle = "--")
    except:
        pass


plt.xlabel(f"{line} [K km/s pc^2]")
plt.ylabel("Number of gas particles")
plt.title("gal600 test")
plt.legend()


figure_name = f"luminosity_distribution_{line}_gal600_test.png"
plt.savefig(figure_name)
print(f"Figure saved as {figure_name}")
plt.show()



plt.scatter(
    np.log10(runs_gal600["expected_from_luminosity_per_mass_by_dividing_to_4pi"]["data"][line]),
    np.log10(runs_gal600["interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200"]["data"][line]), 
    label = "expected", color = "black"
)
plt.plot([ -5, 6], [-5, 6], linestyle = "--", color = "red")
plt.xlabel(f"expected {line} [K km/s pc^2]")
plt.ylabel(f"RBFInterpolator_N200 {line} [K km/s pc^2]")
plt.title("gal600 test")
plt.legend()
plt.xlim(0,4)
plt.ylim(0,4)
plt.grid(True)
plt.show()  

plt.scatter(
    np.log10(runs_gal600["expected_from_luminosity_per_mass_by_dividing_to_4pi"]["data"][line]),
    np.log10(runs_gal600["interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N1000"]["data"][line]), 
    label = "expected", color = "black"
)
plt.plot([ -5, 6], [-5, 6], linestyle = "--", color = "red")
plt.xlabel(f"expected {line} [K km/s pc^2]")
plt.ylabel(f"RBFInterpolator_N1000 {line} [K km/s pc^2]")
plt.title("gal600 test")
plt.legend()
plt.xlim(0,4)
plt.ylim(0,4)
plt.grid(True)
plt.show()
# Out:
# /scratch/dtolgay/cloudy_runs/z_0/gal600_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N100_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/gal600_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/gal600_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N300_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/gal600_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N1000_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/gal600_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N10000_smoothingLength_interpolation.txt
# ----------- /scratch/dtolgay/cloudy_runs/z_0/gal600_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N10000_smoothingLength_interpolation.txt not found
# ...

# %%
base_fdir = "/scratch/dtolgay/cloudy_runs/z_0/gal115_test"

runs_gal115 = {
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N100": {
        "label": "L/M/4π RBFInterpolator N100",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N100_smoothingLength_interpolation.txt",
        "color": "purple",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200": {
        "label": "L/M/4π RBFInterpolator N200",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200_smoothingLength_interpolation.txt",
        "color": "magenta",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N300": {
        "label": "L/M/4π RBFInterpolator N300",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N300_smoothingLength_interpolation.txt",
        "color": "cyan",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N1000": {
        "label": "L/M/4π RBFInterpolator N1000",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N1000_smoothingLength_interpolation.txt",
        "color": "blue",
    },
    "interpolated_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N10000": {
        "label": "L/M/4π RBFInterpolator N10000",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N10000_smoothingLength_interpolation.txt",
        "color": "green",
    },
    "expected_from_luminosity_per_mass_by_dividing_to_4pi": {
        "label": "L/M/4π expected",
        "file_name": "luminosity_from_luminosity_per_mass_by_dividing_to_4pi_smoothingLength_expected.txt",
        "color": "brown",
    },
}

for run in runs_gal115.keys():
    try:
        path_to_file = f"{base_fdir}/{runs_gal115[run]['file_name']}"
        print(path_to_file)
        runs_gal115[run]["data"], _ = readfiles.read_interpolated_files_usingFilePath2(path = path_to_file, interpolation_type = "line_emissions")
    except:
        path_to_file = f"{base_fdir}/{runs_gal115[run]['file_name']}"
        print(f"----------- {path_to_file} not found")



# Plot the distribution of luminosities for different interpolators

line = "L_co_10"
bins = np.linspace(-5, 8, 100)

for run in runs_gal115.keys():

    try:
        total_luminosity = np.sum(runs_gal115[run]["data"][line])

        luminosities = runs_gal115[run]["data"][line]
        plt.hist(
            np.log10(luminosities), 
            bins = bins, alpha = 0.5, 
            label = f"run: {runs_gal115[run]['label']}, total L = {total_luminosity:.2e} K km/s pc^2", 
            color = runs_gal115[run]["color"]
        )
        plt.axvline(np.median(np.log10(luminosities)), color = runs_gal115[run]["color"], linestyle = "--")
    except:
        pass


plt.xlabel(f"{line} [K km/s pc^2]")
plt.ylabel("Number of gas particles")
plt.title("gal115 test")
plt.legend()

figure_name = f"luminosity_distribution_{line}_gal115_test.png"
plt.savefig(figure_name)
print(f"Figure saved as {figure_name}")
# Out:
# /scratch/dtolgay/cloudy_runs/z_0/gal115_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N100_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/gal115_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/gal115_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N300_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/gal115_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N1000_smoothingLength_interpolation.txt
# /scratch/dtolgay/cloudy_runs/z_0/gal115_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N10000_smoothingLength_interpolation.txt
# ----------- /scratch/dtolgay/cloudy_runs/z_0/gal115_test/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N10000_smoothingLength_interpolation.txt not found
# ...

# %% [markdown]
# # FIRE Galaxies

# %%
galaxies = {
    "gal10 - L/A" : {
        "label": "gal10 - flux",
        "fdir": "/scratch/dtolgay/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal10/voronoi_1e5/line_emissions_RBFInterpolator_smoothingLength.txt",
        "color": "black",
    },
    "gal10 - L/M": {
        "label": "gal10 - luminosity per mass",
        "fdir": "/scratch/dtolgay/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal10/voronoi_1e5/luminosity_from_luminosity_per_mass_RBFInterpolator_smoothingLength.txt",
        "color": "gray"
    },
    "gal10 - L/M 4π RBFInterpolator_N200": {
        "label": "gal10 - L/M/4π RBFInterpolator_N200",
        "fdir": "/scratch/dtolgay/post_processing_fire_outputs/skirt/runs_hden_radius/firebox/z0.0/gal10/voronoi_1e5/luminosity_from_luminosity_per_mass_by_dividing_to_4pi_RBFInterpolator_N200_smoothingLength.txt",
        "color": "blue"
    },
}

for key, value in galaxies.items():
    galaxies[key]["data"], _ = readfiles.read_interpolated_files_usingFilePath2(path = value["fdir"], interpolation_type = "line_emissions")



line = "L_co_10"
for key, value in galaxies.items():
    gas_luminosity = value["data"][line]
    
    total_luminosity = np.sum(gas_luminosity)

    bins = np.linspace(-5, 8, 100)
    luminosities = gas_luminosity
    plt.hist(
        np.log10(luminosities), 
        bins = 30, alpha = 0.5, 
        label = f"{value['label']}, total L = {total_luminosity:.2e} K km/s pc^2", 
        color = value["color"]
    )
    plt.axvline(np.median(np.log10(luminosities)), color = value["color"], linestyle = "--")

plt.xlabel(f"{line} [K km/s pc^2]")
plt.ylabel("Number of gas particles")
plt.legend()
plt.show()


line = "L_h_alpha"
for key, value in galaxies.items():
    gas_luminosity = value["data"][line]
    
    total_luminosity = np.sum(gas_luminosity)

    bins = np.linspace(-5, 8, 100)
    luminosities = gas_luminosity
    plt.hist(
        np.log10(luminosities), 
        bins = 30, alpha = 0.5, 
        label = f"{value['label']}, total L = {total_luminosity:.2e} erg/s", 
        color = value["color"]
    )
    plt.axvline(np.median(np.log10(luminosities)), color = value["color"], linestyle = "--")

plt.xlabel(f"{line} [erg / s]")
plt.ylabel("Number of gas particles")
plt.legend()
plt.show()



line = "L_ly_alpha"
for key, value in galaxies.items():
    gas_luminosity = value["data"][line]
    
    total_luminosity = np.sum(gas_luminosity)

    bins = np.linspace(-5, 8, 100)
    luminosities = gas_luminosity
    plt.hist(
        np.log10(luminosities), 
        bins = 30, alpha = 0.5, 
        label = f"{value['label']}, total L = {total_luminosity:.2e} erg/s", 
        color = value["color"]
    )
    plt.axvline(np.median(np.log10(luminosities)), color = value["color"], linestyle = "--")

plt.xlabel(f"{line} [erg / s]")
plt.ylabel("Number of gas particles")
plt.legend()
plt.show()
